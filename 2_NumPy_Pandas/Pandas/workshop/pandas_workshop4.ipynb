# %% [markdown]
# # Pandas Workshop 4
#
# This workshop covers topics from the lecture that are not practised in Workshops 1–3:
# - **Section A** — Pandas Series
# - **Section B** — Data Exploration (`info`, `describe`, `value_counts`)
# - **Section C** — Sorting & Ranking
# - **Section D** — Merging & Concatenation
# - **Section E** — Apply & Map Transformations
#
# **Data file used:** `data.csv` (workout sessions dataset — Duration, Pulse, Maxpulse, Calories)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ## Section A — Pandas Series
#
# A `Series` is a 1D labelled array. The key distinction:
# - **`iloc`** — integer position (exclusive slicing, like Python lists)
# - **`loc`** — label-based access (inclusive slicing)

# %% [markdown]
# **A1.** Create a Series of monthly average temperatures (°C) for Singapore:
# ```
# Jan=26.6, Feb=27.1, Mar=27.5, Apr=28.0, May=28.3,
# Jun=28.2, Jul=27.9, Aug=27.9, Sep=27.6, Oct=27.3, Nov=26.9, Dec=26.5
# ```
# Use month names as the index. Then:
# 1. Print the temperature for **March** using both `iloc` and `loc`
# 2. Print temperatures for **Apr through Jun** using `loc` slicing (inclusive)
# 3. Print temperatures for the first 3 months using `iloc` slicing (exclusive)
# 4. Find the **hottest** and **coolest** month using `.idxmax()` / `.idxmin()`

# %%
# A1

# %% [markdown]
# **A2.** Create this Series of product stock counts:
# ```python
# pd.Series({'Apple': 50, 'Banana': 0, 'Cherry': 120, 'Date': 0, 'Elderberry': 30})
# ```
# 1. Use boolean indexing to find products **out of stock** (value == 0)
# 2. Use boolean indexing to find products with stock **> 40**
# 3. Update the stock for `'Banana'` to 75 and `'Date'` to 20, then print the updated Series
# 4. Compute the **total stock** and **average stock** across all products

# %%
# A2

# %% [markdown]
# **A3.** Create two sales Series for the same products (same index):
# ```python
# q1 = pd.Series([100, 150, 80, 200], index=['A', 'B', 'C', 'D'])
# q2 = pd.Series([120, 90, 160, 50],  index=['A', 'B', 'C', 'D'])
# ```
# 1. Compute Q1 + Q2 total sales using vectorized addition
# 2. Find the percentage change from Q1 to Q2: `(q2 - q1) / q1 * 100`
# 3. Which product had the **largest increase**? Which had the **largest decrease**?

# %%
# A3

# %% [markdown]
# ---
# ## Section B — Data Exploration
#
# Use `info()`, `describe()`, and `value_counts()` to quickly profile a dataset before modelling.

# %% [markdown]
# **B1.** Load `data.csv` and run a complete data profile:
# 1. Print `info()` — what columns exist, how many non-null values each has, and the data types
# 2. Print `describe()` — note the min, max, mean, and 25th/75th percentiles for each column
# 3. Use `value_counts()` on the `Duration` column — which duration appears most often?
# 4. How many **unique** values does `Pulse` have? (use `.nunique()`)

# %%
# B1

# %% [markdown]
# **B2.** Load `data.csv`. Compute the following statistics **without** using `describe()`:
# 1. Mean of each numeric column using `.mean()`
# 2. Standard deviation of each column using `.std()`
# 3. Minimum and maximum of `Calories` using `.min()` / `.max()`
# 4. The **correlation** between `Pulse` and `Calories` using `.corr()` on the two columns
#    - Is the correlation positive or negative? What does it tell you?

# %%
# B2

# %% [markdown]
# **B3.** Load `data.csv`. Use `value_counts()` and `nunique()` to answer:
# 1. What are the top 3 most common `Duration` values?
# 2. What fraction (%) of workouts lasted exactly 60 minutes?
# 3. How many unique `Maxpulse` values appear in the dataset?
# 4. Create a binned version of `Calories` using `pd.cut()` with bins `[0, 200, 400, 600, 2000]` and labels `['Low', 'Medium', 'High', 'Very High']`. Print the `value_counts()` of this binned column.

# %%
# B3

# %% [markdown]
# ---
# ## Section C — Sorting & Ranking

# %% [markdown]
# **C1.** Load `data.csv`.
# 1. Sort by `Calories` **ascending** — print the first 5 rows (lowest calorie burn)
# 2. Sort by `Calories` **descending** — print the first 5 rows (highest calorie burn)
# 3. Use `nlargest(5, 'Calories')` and confirm you get the same top-5 as step 2
# 4. Use `nsmallest(3, 'Duration')` — what is the shortest workout duration in the dataset?

# %%
# C1

# %% [markdown]
# **C2.** Load `data.csv`.
# 1. Sort by `Duration` ascending, then by `Calories` descending (multi-column sort)
# 2. For workouts lasting exactly 60 minutes, which had the highest `Pulse`?
#    Use filtering + `sort_values` or `nlargest`.
# 3. After sorting, use `reset_index(drop=True)` on the result and print the first 5 rows.

# %%
# C2

# %% [markdown]
# ---
# ## Section D — Merging & Concatenation
#
# `pd.merge()` is equivalent to SQL JOIN. `pd.concat()` stacks DataFrames vertically or horizontally.

# %% [markdown]
# **D1.** Create the following two DataFrames:
# ```python
# students = {'student_id': [1, 2, 3, 4, 5],
#             'name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
#             'class_id': [101, 102, 101, 103, 102]}
#
# classes  = {'class_id': [101, 102, 104],
#             'class_name': ['Data Science', 'Machine Learning', 'Statistics']}
# ```
# 1. Perform an **inner join** on `class_id` — how many rows result?
# 2. Perform a **left join** — how many rows now? Which student has `NaN` for `class_name`?
# 3. Perform an **outer join** — how many rows? What class appears with no students?

# %%
# D1

# %% [markdown]
# **D2.** Create two DataFrames representing workout logs from different months:
# ```python
# # January log
# df_jan = {'date': ['2024-01-01','2024-01-03','2024-01-05'],
#           'duration': [45, 60, 30], 'calories': [300, 450, 200]}
#
# # February log
# df_feb = {'date': ['2024-02-01','2024-02-04','2024-02-06'],
#           'duration': [60, 60, 45], 'calories': [400, 380, 280]}
# ```
# 1. Add a `month` column (`'Jan'` / `'Feb'`) to each before combining
# 2. Concatenate vertically with `ignore_index=True`
# 3. Group the combined DataFrame by `month` and compute total calories
# 4. Concatenate horizontally a new DataFrame of heart rates alongside the Jan log (`axis=1`)

# %%
# D2

# %% [markdown]
# **D3.** Load `data.csv`. Split it into two halves using `iloc`:
# - `df_first` = first 85 rows
# - `df_second` = remaining rows
#
# 1. Concatenate them back and verify the row count matches the original
# 2. Use `pd.concat` with `keys=['first', 'second']` to create a **MultiIndex** DataFrame
# 3. Access all rows from the `'first'` key using `.loc['first']`

# %%
# D3

# %% [markdown]
# ---
# ## Section E — Apply & Map Transformations
#
# `apply()` runs any function over rows or columns. `map()` replaces values via a dictionary or function.

# %% [markdown]
# **E1.** Load `data.csv`. Use `apply()` to create new columns:
# 1. Add `Calories_kJ` = Calories × 4.184 (convert kcal to kJ) using `.apply()`
# 2. Add `Zone` column: `'Fat Burn'` if Pulse < 100, `'Cardio'` if 100 ≤ Pulse < 140, `'Peak'` if ≥ 140
# 3. Count how many sessions fall into each `Zone` using `value_counts()`

# %%
# E1

# %% [markdown]
# **E2.** Load `data.csv`. Use row-wise `apply(axis=1)` to create a summary string:
# 1. Create a `summary` column where each row reads:
#    `"60min | P:110 | C:409.1"` (Duration | Pulse | Calories, rounded to 1 dp)
# 2. Add an `Efficiency` column = Calories / Duration (kcal per minute), computed with `.apply()`
# 3. Find the **5 most efficient** workouts using `nlargest(5, 'Efficiency')`

# %%
# E2

# %% [markdown]
# **E3.** Create a DataFrame of 10 employees:
# ```python
# np.random.seed(7)
# df_emp = pd.DataFrame({
#     'name':   [f'Emp{i}' for i in range(1, 11)],
#     'dept':   np.random.choice(['Sales','Eng','HR','Finance'], 10),
#     'rating': np.random.choice(['A','B','C'], 10),
#     'salary': np.random.randint(40000, 100000, 10)
# })
# ```
# 1. Use `.map({'A':4, 'B':3, 'C':2})` to convert `rating` to a numeric `grade` column
# 2. Use `.apply()` on `salary` to add a `bonus` column (10% for salary > 70K, 5% otherwise)
# 3. Group by `dept` and compute mean `salary` and mean `grade`

# %%
# E3

# %% [markdown]
# # Pandas Workshop 3

# %% [markdown]
# 1) Import pandas package;
#    import pyplot of matplotlib package;
#    import seaborn package

# %% [markdown]
# 2) Load staff.csv into dataframe df and display it

# %% [markdown]
# 3) Find all staff with salary less than a certain amount, e.g. 6000

# %% [markdown]
# 4) List all staff for a given department, e.g. Sales

# %% [markdown]
# 5) Find the department with the highest number of staff

# %% [markdown]
# 6) Plot the total staff salary for each department

# %% [markdown]
# # Pandas — Lecture Notebook

# %% [markdown]
# ---
# ## Part 1 — Series: Labelled 1D Arrays
#
# A **Series** is a 1D labelled array — think of it as a single column in a spreadsheet. Each element has an **index label** (default: 0, 1, 2… or custom names). Values are **mutable**, but the size is **immutable** after creation.
#
# | Accessor | Behaviour |
# |---|---|
# | `.iloc[n]` | Integer position (0-based) |
# | `.loc['label']` | Label name |
# | `iloc[a:b]` slicing | **Exclusive** — returns a, a+1, … b-1 |
# | `loc['a':'b']` slicing | **Inclusive** — returns a … b |

# %%
import pandas as pd

# Default integer index
s1 = pd.Series([21, 32, 45])
print(f"Default index:\n{s1}\n")

# Custom named index
s2 = pd.Series([21, 32, 45],
               index=['mary', 'john', 'james'])
print(f"Named index:\n{s2}\n")

# Access by position (iloc) vs label (loc)
print(f"iloc[1] = {s2.iloc[1]}")
print(f"loc['john'] = {s2.loc['john']}")

# CRITICAL: loc slicing is INCLUSIVE!
print(f"\niloc[0:2]:\n{s2.iloc[0:2]}")  # mary, john
print(f"\nloc['mary':'john']:\n{s2.loc['mary':'john']}")  # mary, john (inclusive!)

# Update value
s2['john'] = 38
print(f"\nAfter update:\n{s2}")
# Out:
# Default index:
# 0    21
# 1    32
# 2    45
# dtype: int64
#
# Named index:
# mary     21
# john     32
# james    45
# dtype: int64
#
# iloc[1] = 32
# loc['john'] = 32
#
# iloc[0:2]:
# mary    21
# john    32
# dtype: int64
#
# loc['mary':'john']:
# mary    21
# john    32
# dtype: int64
#
# After update:
# mary     21
# john     38
# james    45
# dtype: int64

# %% [markdown]
# ### Part 1 Exercises

# %% [markdown]
# **Exercise 1.1** — Create a Series of stock closing prices with ticker symbols as the index (e.g., `AAPL=182.5`, `GOOG=140.2`, `MSFT=378.9`, `AMZN=185.0`, `TSLA=250.3`). Access Microsoft's price using both `iloc` (by position) and `loc` (by label). Then update TSLA's price to 260.0 and print the Series.

# %%
# Exercise 1.1

# 1. Create series of stock closing prices with ticker symbols as index
series = pd.Series([ 182.5, 140.2, 378.9, 185.0, 250.3 ], index = [ 'AAPL', 'GOOG', 'MSFT', 'AMZN', 'TSLA' ])
print(series)

# 2. Access Microsoft's price using both iloc and loc
micro_p1 = series.iloc[2]
micro_p2 = series.loc['MSFT']
print(f"\nMicrosoft Price by iloc: {micro_p1}, By loc: {micro_p2}")

# 3. Update TSLA price to 260.0 and print series
series['TSLA'] = 260.0
print(series)
# Out:
# AAPL    182.5
# GOOG    140.2
# MSFT    378.9
# AMZN    185.0
# TSLA    250.3
# dtype: float64
#
# Microsoft Price by iloc: 378.9, By loc: 378.9
# AAPL    182.5
# GOOG    140.2
# MSFT    378.9
# AMZN    185.0
# TSLA    260.0
# dtype: float64

# %% [markdown]
# **Exercise 1.2** — Create two Series `a` and `b`:
# - `a = pd.Series([10, 20, 30], index=['x', 'y', 'z'])`
# - `b = pd.Series([1, 2, 3, 4], index=['y', 'z', 'w', 'v'])`
#
# Add them together (`a + b`) and print the result. Explain why some values are `NaN`. Then fill those `NaN`s with 0 using `.fillna(0)`.

# %%
# Exercise 1.2

# 1. Create two series a and b
a = pd.Series([ 10, 20, 30 ], index = [ 'x', 'y', 'z' ])
b = pd.Series([ 1, 2, 3, 4 ], index = [ 'y', 'z', 'w', 'v' ])

print(f"A: {a}\n\nB: {b}")

# 2. Add a and b and print result
result = a + b
print("\nA + B:", result)

# Some values are NaN because not both series contains certain values
# Fill NaNs with 0
result = result.fillna(0)
print("\n Filled:", result)
# Out:
# A: x    10
# y    20
# z    30
# dtype: int64
#
# B: y    1
# z    2
# w    3
# v    4
# dtype: int64
#
# A + B: v     NaN
# w     NaN
# x     NaN
# y    21.0
# z    32.0
# dtype: float64
#
#  Filled: v     0.0
# w     0.0
# x     0.0
# y    21.0
# z    32.0
# dtype: float64

# %% [markdown]
# **Exercise 1.3** — Create a Series from this dictionary of country populations (in millions):
# ```python
# {'China': 1412, 'India': 1380, 'USA': 331, 'Indonesia': 273, 'Pakistan': 225, 'Brazil': 214}
# ```
# Use boolean indexing to print only countries with population > 300 million. Then sort the Series in descending order.

# %%
# Exercise 1.3
country_pops = {'China': 1412, 'India': 1380, 'USA': 331, 'Indonesia': 273, 'Pakistan': 225, 'Brazil': 214}

# 1. Create series from dictionary
series = pd.Series(country_pops.values(), index = country_pops.keys())
print(series)

# 2. Use boolean indexing to print only countries with pop > 300mill, then sort in desc order
# bool mask
mask = series > 300

# Extract values
alt_series = series.where(mask).sort_values(ascending = False)
print("\n", alt_series)
# Out:
# China        1412
# India        1380
# USA           331
# Indonesia     273
# Pakistan      225
# Brazil        214
# dtype: int64
#
#  China        1412.0
# India        1380.0
# USA           331.0
# Indonesia       NaN
# Pakistan        NaN
# Brazil          NaN
# dtype: float64

# %% [markdown]
# **Exercise 1.4** — Demonstrate the `iloc` vs `loc` slicing difference on this Series:
# ```python
# s = pd.Series([100, 200, 300, 400, 500], index=['a', 'b', 'c', 'd', 'e'])
# ```
# Print `s.iloc[1:3]` and `s.loc['b':'d']`. State how many elements each returns and why they differ.

# %%
# Exercise 1.4

s = pd.Series([100, 200, 300, 400, 500], index=['a', 'b', 'c', 'd', 'e'])

# Print iloc & loc; state how many elements each returns and why they differ
print("Iloc:", s.iloc[1:3])
print("\nLoc:", s.loc['b':'d'])

# Iloc returns 2 elements, loc returns 3 elements. 
# They differ because loc returns result inclusive of last element.
# Out:
# Iloc: b    200
# c    300
# dtype: int64
#
# Loc: b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
# **Exercise 1.5** — Create a Series of 6 exam scores: `[72, 85, 91, 60, 78, 88]`. Compute and print: mean, max, min, and sum. Then normalize the scores to a 0–1 range using vectorized operations (no loops): `normalized = (s - s.min()) / (s.max() - s.min())`.

# %%
# Exercise 1.5

# Create series
scores = pd.Series([ 72, 85, 91, 60, 78, 88 ])
print("Exam scores:", scores)

# Compute & print mean max min sum
mean = sum(scores) / scores.size
maxi = scores.max()
mini = scores.min()
total = scores.sum()

print(f"\nMean: {mean}\nMax: {maxi}\nMin: {mini}\nSum: {total}")

# Normalise scores to 0-1 range using vectorised ops
# Normalised = (s - s.min()) / s.max() - s.min())
norm = (scores - mini) / (maxi - mini)
print(f"\nNormalised:\n{norm}")
# Out:
# Exam scores: 0    72
# 1    85
# 2    91
# 3    60
# 4    78
# 5    88
# dtype: int64
#
# Mean: 79.0
# Max: 91
# Min: 60
# Sum: 474
#
# Normalised:
# 0    0.387097
# 1    0.806452
# 2    1.000000
# 3    0.000000
# 4    0.580645
# 5    0.903226
# dtype: float64

# %% [markdown]
# ---
# ## Part 2 — DataFrame: The Core Data Structure for ML
#
# A **DataFrame** is a 2D labelled table — rows × columns. Each column is a Series sharing the same index. DataFrames are the primary structure for ML: features are columns, observations are rows.

# %%
import pandas as pd

# Method 1: From dictionary (most common!)
df = pd.DataFrame({
    'name': ['Mary', 'John', 'James'],
    'age': [21, 32, 45],
    'height': [1.7, 1.8, 1.6],
    'weight': [55, 65, 50]
})
print(f"From dict:\n{df}\n")

# Method 2: From list of lists + column names
df2 = pd.DataFrame(
    [[21, 1.7, 55], [32, 1.8, 65], [45, 1.6, 50]],
    columns=['age', 'height', 'weight'],
    index=['mary', 'john', 'james']
)
print(f"From lists + custom index:\n{df2}\n")

# Key attributes
print(f"Shape: {df2.shape}")
print(f"Columns: {list(df2.columns)}")
print(f"Index: {list(df2.index)}")
print(f"Dtypes:\n{df2.dtypes}")
# Out:
# From dict:
#     name  age  height  weight
# 0   Mary   21     1.7      55
# 1   John   32     1.8      65
# 2  James   45     1.6      50
#
# From lists + custom index:
#        age  height  weight
# mary    21     1.7      55
# john    32     1.8      65
# james   45     1.6      50
#
# Shape: (3, 3)
# Columns: ['age', 'height', 'weight']
# Index: ['mary', 'john', 'james']
# Dtypes:
# age         int64
# height    float64
# weight      int64
# dtype: object

# %% [markdown]
# ### Exploring Your Data
#
# Before modelling, always **inspect** the DataFrame to understand its shape, types, and statistics.

# %%
import pandas as pd
import numpy as np

# Create a sample dataset
np.random.seed(42)
df = pd.DataFrame({
    'name': ['Alice','Bob','Charlie','Diana','Eve',
             'Frank','Grace','Hank','Iris','Jack'],
    'age': np.random.randint(20, 60, 10),
    'salary': np.random.randint(30000, 90000, 10),
    'dept': np.random.choice(['Sales','Eng','HR'], 10)
})
print(f"Shape: {df.shape}\n")
print(f"First 3 rows:\n{df.head(3)}\n")
print(f"Statistics:\n{df.describe()}\n")
print(f"Dept counts:\n{df['dept'].value_counts()}")
# Out:
# Shape: (10, 4)
#
# First 3 rows:
#       name  age  salary   dept
# 0    Alice   58   77191  Sales
# 1      Bob   48   74131  Sales
# 2  Charlie   34   46023    Eng
#
# Statistics:
#             age        salary
# count  10.00000     10.000000
# mean   40.50000  57446.900000
# std    11.16791  24357.262884
# min    27.00000  30769.000000
# 25%    31.00000  33152.500000
# 50%    39.00000  58556.500000
# 75%    46.50000  76426.000000
# max    58.00000  89735.000000
#
# Dept counts:
# dept
# Sales    5
# HR       3
# Eng      2
# Name: count, dtype: int64

# %% [markdown]
# ### Part 2 Exercises

# %% [markdown]
# **Exercise 2.1** — Create a student grade DataFrame from a dictionary with columns `name`, `math`, `english`, `science` for 5 students (invent the data). Compute each student's average score as a new column `avg`. Print the DataFrame sorted by `avg` descending.

# %%
# Exercise 2.1

# Invent data dictionary
data = {
    'name': ['Alice', 'Ben', 'Clara', 'Daniel', 'Eva'],
    'math': [88, 76, 95, 69, 84],
    'english': [92, 81, 87, 73, 90],
    'science': [85, 79, 93, 70, 88]
}

# Create df from dict
grades = pd.DataFrame(data)
print(grades)

# Compute each student's avg score as new col avg and print (desc)
grades['avg'] = grades[['math', 'english', 'science']].mean(axis = 1)
print("\n", grades.sort_values(by = 'avg', ascending = False))
# Out:
#      name  math  english  science
# 0   Alice    88       92       85
# 1     Ben    76       81       79
# 2   Clara    95       87       93
# 3  Daniel    69       73       70
# 4     Eva    84       90       88
#
#       name  math  english  science        avg
# 2   Clara    95       87       93  91.666667
# 0   Alice    88       92       85  88.333333
# 4     Eva    84       90       88  87.333333
# 1     Ben    76       81       79  78.666667
# 3  Daniel    69       73       70  70.666667

# %% [markdown]
# **Exercise 2.2** — Load `data.csv` (exercise file is in the `Pandas/` folder) using `pd.read_csv('data.csv')`. Use `head()`, `tail(3)`, `shape`, `info()`, `describe()`, and `dtypes` to explore it. Print each result with a descriptive label.

# %%
# Exercise 2.2

# Load staff-1.csv
staff = pd.read_csv('staff-1.csv')
print(staff)

print(f"\nStaff head:\n{staff.head()}")
print(f"\nStaff tail:\n{staff.tail(3)}")
print(f"\nStaff shape:\n{staff.shape}")
print(f"\nInfo:\n{staff.info()}")
print(f"\nDescription:\n{staff.describe()}")
print(f"\nData Types:\n{staff.dtypes}")
# Out:
#      Name  Age  Salary Gender   Department
# 0    John   31    7500      M        Sales
# 1    Lynn   35   15000      F  Engineering
# 2   James   29    8500      M        Sales
# 3   Larry   28   12200      M        Sales
# 4    Mary   44    5500      F      Finance
# 5    Lisa   33    5500      F        Sales
# 6   Scott   29    9500      M      Finance
# 7  Jenson   38    7850      M  Engineering
# 8     May   42    9000      F  Engineering
#
# Staff head:
#     Name  Age  Salary Gender   Department
# 0   John   31    7500      M        Sales
# 1   Lynn   35   15000      F  Engineering
# 2  James   29    8500      M        Sales
# 3  Larry   28   12200      M        Sales
# 4   Mary   44    5500      F      Finance
#
# Staff tail:
#      Name  Age  Salary Gender   Department
# 6   Scott   29    9500      M      Finance
# 7  Jenson   38    7850      M  Engineering
# 8     May   42    9000      F  Engineering
#
# Staff shape:
# (9, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      str
#  1   Age         9 non-null      int64
#  2   Salary      9 non-null      int64
#  3   Gender      9 non-null      str
#  4   Department  9 non-null      str
# dtypes: int64(2), str(3)
# memory usage: 492.0 bytes
#
# Info:
# None
#
# Description:
#              Age        Salary
# count   9.000000      9.000000
# mean   34.333333   8950.000000
# std     5.873670   3057.572567
# min    28.000000   5500.000000
# 25%    29.000000   7500.000000
# 50%    33.000000   8500.000000
# 75%    38.000000   9500.000000
# max    44.000000  15000.000000
#
# Data Types:
# Name            str
# Age           int64
# Salary        int64
# Gender          str
# Department      str
# dtype: object

# %% [markdown]
# **Exercise 2.3** — Create a DataFrame from a **list of lists** representing a product inventory with columns `Product`, `Price`, `Quantity` (at least 4 rows). Add a computed column `Revenue = Price * Quantity`. Print the DataFrame and the total revenue using `.sum()`.

# %%
# Exercise 2.3

# Generate list
inventory = [
    ['Laptop', 1200, 5],
    ['Mouse', 25, 40],
    ['Keyboard', 80, 15],
    ['Monitor', 300, 8]
]

# Create df of list of lists
inv_df = pd.DataFrame(inventory, columns = ['Product', 'Price', 'Quantity'])
print(inv_df)

# Add computed column revenue
inv_df['Revenue'] = (inv_df['Price'] * inv_df['Quantity'])
print("\n", inv_df)
print("\nTotal Revenue:", inv_df['Revenue'].sum())
# Out:
#     Product  Price  Quantity
# 0    Laptop   1200         5
# 1     Mouse     25        40
# 2  Keyboard     80        15
# 3   Monitor    300         8
#
#      Product  Price  Quantity  Revenue
# 0    Laptop   1200         5     6000
# 1     Mouse     25        40     1000
# 2  Keyboard     80        15     1200
# 3   Monitor    300         8     2400
#
# Total Revenue: 10600

# %% [markdown]
# **Exercise 2.4** — Create a 4×3 DataFrame from a NumPy array of random integers between 1 and 100 (`np.random.randint`). Assign column names `['A', 'B', 'C']` and a custom string index `['row1', 'row2', 'row3', 'row4']`. Use `value_counts()` on column `'A'` (or the binned version if all values are unique).

# %%
# Exercise 2.4
import numpy as np

np.random.seed(42)
rand = np.random.randint(1, 101, size = (4, 3))
print(rand)

# Create 4 x 3
rand_df = pd.DataFrame(rand, columns = ['A', 'B', 'C'], index = ['row1', 'row2', 'row3', 'row4'])
print("\n", rand_df)

print("\n", rand_df['A'].value_counts())
# Out:
# [[ 52  93  15]
#  [ 72  61  21]
#  [ 83  87  75]
#  [ 75  88 100]]
#
#         A   B    C
# row1  52  93   15
# row2  72  61   21
# row3  83  87   75
# row4  75  88  100
#
#  A
# 52    1
# 72    1
# 83    1
# 75    1
# Name: count, dtype: int64

# %% [markdown]
# **Exercise 2.5** — Load `data.csv`. Use `describe()` to get summary statistics. Answer these questions in code (use `.idxmax()` and `.std()`):
# 1. Which column has the highest **mean** value?
# 2. Which column has the highest **standard deviation**?
# 3. What is the **median** of each numeric column? (use `.median()`)

# %%
# Exercise 2.5

# Load staff-1.csv
staff_df = pd.read_csv('staff-1.csv')
print(staff_df)

# 1. Which col has highest mean value
highest_mean = staff_df.mean(numeric_only = True).idxmax()
print("\nColumn with highest mean:", highest_mean)

# 2. Which col has the highest SD?
highest_sd = staff_df.std(numeric_only = True).idxmax()
print("\nColumn with highest SD:", highest_sd)

# 3. Median of each numeric column
median = staff_df.median(numeric_only = True)
print(f"\nMedian of each numeric column:\n{median}")
# Out:
#      Name  Age  Salary Gender   Department
# 0    John   31    7500      M        Sales
# 1    Lynn   35   15000      F  Engineering
# 2   James   29    8500      M        Sales
# 3   Larry   28   12200      M        Sales
# 4    Mary   44    5500      F      Finance
# 5    Lisa   33    5500      F        Sales
# 6   Scott   29    9500      M      Finance
# 7  Jenson   38    7850      M  Engineering
# 8     May   42    9000      F  Engineering
#
# Column with highest mean: Salary
#
# Column with highest SD: Salary
#
# Median of each numeric column:
# Age         33.0
# Salary    8500.0
# dtype: float64

# %% [markdown]
# ---
# ## Part 3 — Selecting, Filtering & Indexing Data
#
# Pandas offers multiple ways to select data. The two primary accessors are:
# - **`iloc`** — integer **i**ndex position
# - **`loc`** — **l**abel-based access
#
# Boolean filtering lets you extract rows that satisfy a condition — the foundation of data querying.

# %%
import pandas as pd

df = pd.DataFrame({
    'age': [21, 32, 45],
    'height': [1.7, 1.8, 1.6],
    'weight': [55, 65, 50]
}, index=['mary', 'john', 'james'])
print(f"DataFrame:\n{df}\n")

# Column selection
print(f"df['age'] (Series):\n{df['age']}\n")
print(f"df[['age','weight']] (DataFrame):")
print(f"{df[['age','weight']]}\n")

# Row by position (iloc)
print(f"iloc[1] (Series):\n{df.iloc[1]}\n")
print(f"iloc[[1]] (DataFrame):\n{df.iloc[[1]]}\n")

# Row by label (loc)
print(f"loc['john','age'] = {df.loc['john','age']}")

# Slicing rows + cols
print(f"\niloc[1:, 1:]:\n{df.iloc[1:, 1:]}")
# Out:
# DataFrame:
#        age  height  weight
# mary    21     1.7      55
# john    32     1.8      65
# james   45     1.6      50
#
# df['age'] (Series):
# mary     21
# john     32
# james    45
# Name: age, dtype: int64
#
# df[['age','weight']] (DataFrame):
#        age  weight
# mary    21      55
# john    32      65
# james   45      50
#
# iloc[1] (Series):
# age       32.0
# height     1.8
# weight    65.0
# Name: john, dtype: float64
#
# iloc[[1]] (DataFrame):
#       age  height  weight
# john   32     1.8      65
#
# loc['john','age'] = 32
#
# iloc[1:, 1:]:
#        height  weight
# john      1.8      65
# james     1.6      50

# %% [markdown]
# ### Boolean Filtering
#
# Filter rows by applying conditions — similar to SQL `WHERE`.
# **Important**: when combining conditions, always use parentheses and `&` / `|` (not `and` / `or`).

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice','Bob','Charlie','Diana','Eve'],
    'age': [25, 30, 35, 28, 42],
    'dept': ['Eng','Sales','Eng','HR','Sales'],
    'salary': [70000, 55000, 80000, 48000, 62000]
})
print(f"All data:\n{df}\n")

# Simple filter
print(f"Age > 30:\n{df[df['age'] > 30]}\n")

# Combined (MUST use parentheses!)
mask = (df['age'] > 25) & (df['dept'] == 'Eng')
print(f"Age>25 AND Eng:\n{df[mask]}\n")

# isin — match against a list
print(f"Dept in Sales/HR:")
print(df[df['dept'].isin(['Sales', 'HR'])])
# Out:
# All data:
#       name  age   dept  salary
# 0    Alice   25    Eng   70000
# 1      Bob   30  Sales   55000
# 2  Charlie   35    Eng   80000
# 3    Diana   28     HR   48000
# 4      Eve   42  Sales   62000
#
# Age > 30:
#       name  age   dept  salary
# 2  Charlie   35    Eng   80000
# 4      Eve   42  Sales   62000
#
# Age>25 AND Eng:
#       name  age dept  salary
# 2  Charlie   35  Eng   80000
#
# Dept in Sales/HR:
#     name  age   dept  salary
# 1    Bob   30  Sales   55000
# 3  Diana   28     HR   48000
# 4    Eve   42  Sales   62000

# %% [markdown]
# ### Part 3 Exercises

# %% [markdown]
# **Exercise 3.1** — Create an employee DataFrame with columns `name`, `dept`, `salary`, `years_exp` for 6 employees. Select only `name` and `salary` as a DataFrame. Select the first 3 rows using `iloc`. Select the last 2 rows using `iloc` with a negative step or slice.

# %%
# Exercise 3.1

# Create employee df
employee_df = pd.DataFrame({
    'name': [ 'John', 'Lily', 'Hazel', 'Paul', 'Dean', 'Moktar' ],
    'dept': [ 'IT', 'BIZ', 'BIZ', 'CS', 'IT', 'BIZ' ],
    'salary': [ 60000, 45000, 40000, 30000, 55000, 50000 ],
    'years_exp': [ 15, 5, 3, 2, 10, 10 ]
})

# Select only name and salary as df
salary_df = employee_df[['name', 'salary']]
print(salary_df)

# Select first 3 rows using iloc
print("\n", salary_df.iloc[:3])

# Select last 2 rows using iloc
print("\n", salary_df.iloc[-2:])
# Out:
#      name  salary
# 0    John   60000
# 1    Lily   45000
# 2   Hazel   40000
# 3    Paul   30000
# 4    Dean   55000
# 5  Moktar   50000
#
#      name  salary
# 0   John   60000
# 1   Lily   45000
# 2  Hazel   40000
#
#       name  salary
# 4    Dean   55000
# 5  Moktar   50000

# %% [markdown]
# **Exercise 3.2** — Using the DataFrame from Exercise 3.1 (or recreate it with a named index), demonstrate:
# 1. `iloc[1:4, 0:2]` — rows 1-3, first 2 columns
# 2. `loc` with named row labels to select a specific row
# 3. `loc` slice to select a range of rows (inclusive)

# %%
# Exercise 3.2

# Clean up indexes
salary_df = salary_df.reset_index(drop = True)

# 1. iloc[1:4, 0:2]
print(salary_df.iloc[1:4, 0:3])

# 2. loc with named row labels
salary_df.index = [ 'row' + str(i) for i in salary_df.index ]
print(f"\n{salary_df.loc['row1']}")

# 3. Loc slice to select range of rows (inclusive)
print(f"\n{salary_df.loc['row2':'row4']}")
# Out:
#     name  salary
# 1   Lily   45000
# 2  Hazel   40000
# 3   Paul   30000
#
# name       Lily
# salary    45000
# Name: row1, dtype: object
#
#        name  salary
# row2  Hazel   40000
# row3   Paul   30000
# row4   Dean   55000

# %% [markdown]
# **Exercise 3.3** — Load `data.csv`. Filter rows where `Calories > 400` AND `Duration >= 60`. Print the count of matching rows and display the first 5 results.

# %%
# Exercise 3.3
import pandas as pd

# Load data.csv
data = pd.read_csv('data.csv')
print(data.shape)

# mask
mask = (data['Calories'] > 400) & (data['Duration'] >= 60)

# Count matching rows
# shape[0] returns number of rows
match = data[mask]
print("\nMatching rows:", match.shape[0])

# Display first 5 results
print(match[:5])
# Out:
# (169, 4)
#
# Matching rows: 34
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 35        60    114       140     415.0
# 51        80    123       146     643.1
# 53        60    118       151     486.0

# %% [markdown]
# **Exercise 3.4** — Load `data.csv`. Apply two separate filters and print the results:
# 1. Rows where `Pulse > 110` **AND** `Maxpulse < 150`
# 2. Rows where `Calories > 500` **OR** `Duration > 180`
#
# For each, print only the count using `.shape[0]`.

# %%
# Exercise 3.4

# Load data.csv
data = pd.read_csv('data.csv')
print(data.shape)

# Apply two separate filters and print results
f1 = (data['Pulse'] > 110) & (data['Maxpulse'] < 150)
f2 = (data['Calories'] > 500) | (data['Duration'] > 180)

print(f"\nFirst result: {data[f1].shape[0]}, Second result: {data[f2].shape[0]}")
# Out:
# (169, 4)
#
# First result: 24, Second result: 21

# %% [markdown]
# **Exercise 3.5** — Create a DataFrame of 8 employees with columns `name`, `dept`, `salary`. Use:
# 1. `.isin(['Engineering', 'Sales'])` to filter by department
# 2. `.str.contains('an', case=False)` to find names containing 'an'
# 3. `.query('salary > 60000 and dept == "Engineering"')` for combined filtering

# %%
# Exercise 3.5

emp_df = pd.DataFrame({
    'name': ['James', 'Mark', 'Louie', 'Sandra', 'Paul', 'Kaia', 'Fiona', 'Joseph'],
    'dept': ['Engineering', 'BIZ', 'CS', 'Sales', 'IT', 'Sales', 'Sales', 'Engineering'],
    'salary': [50000, 45000, 35000, 40000, 55000, 40000, 50000, 65000]
})
print(emp_df)

#1 isin
print(f"\nIsIn:\n{emp_df[emp_df['dept'].isin(['Engineering', 'Sales'])]}")

#2 contains
print(f"\nContains:\n{emp_df[emp_df['name'].str.contains('an')]}")

# 3 query
print(f"\nQuery:\n{emp_df.query('salary > 60000 and dept == "Engineering"')}")
# Out:
#      name         dept  salary
# 0   James  Engineering   50000
# 1    Mark          BIZ   45000
# 2   Louie           CS   35000
# 3  Sandra        Sales   40000
# 4    Paul           IT   55000
# 5    Kaia        Sales   40000
# 6   Fiona        Sales   50000
# 7  Joseph  Engineering   65000
#
# IsIn:
#      name         dept  salary
# 0   James  Engineering   50000
# 3  Sandra        Sales   40000
# 5    Kaia        Sales   40000
# 6   Fiona        Sales   50000
# 7  Joseph  Engineering   65000
#
# Contains:
#      name   dept  salary
# 3  Sandra  Sales   40000
#
# Query:
#      name         dept  salary
# 7  Joseph  Engineering   65000

# %% [markdown]
# ---
# ## Part 4 — Data Wrangling: Modifying, Cleaning & Transforming
#
# Real-world data is always messy. Data wrangling is the process of cleaning, reshaping, and preparing data for analysis or modelling. This typically takes **70–80% of a data scientist's time**.

# %% [markdown]
# ### Adding & Modifying Columns

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Mary', 'John', 'James'],
    'height': [1.7, 1.8, 1.6],
    'weight': [55, 65, 50]
})
print(f"Original:\n{df}\n")

# Add computed column (feature engineering!)
df['bmi'] = df['weight'] / df['height']**2
print(f"With BMI:\n{df}\n")

# Categorise with apply + lambda
df['status'] = df['bmi'].apply(
    lambda x: 'Normal' if x < 25 else 'Overweight'
)
print(f"With status:\n{df}\n")

# Rename columns
df = df.rename(columns={'name': 'patient'})

# Drop column
df = df.drop(columns=['status'])
print(f"After rename + drop:\n{df}")
# Out:
# Original:
#     name  height  weight
# 0   Mary     1.7      55
# 1   John     1.8      65
# 2  James     1.6      50
#
# With BMI:
#     name  height  weight        bmi
# 0   Mary     1.7      55  19.031142
# 1   John     1.8      65  20.061728
# 2  James     1.6      50  19.531250
#
# With status:
#     name  height  weight        bmi  status
# 0   Mary     1.7      55  19.031142  Normal
# 1   John     1.8      65  20.061728  Normal
# 2  James     1.6      50  19.531250  Normal
#
# After rename + drop:
#   patient  height  weight        bmi
# 0    Mary     1.7      55  19.031142
# 1    John     1.8      65  20.061728
# 2   James     1.6      50  19.531250

# %% [markdown]
# ### Handling Missing Data
#
# Missing values (`NaN`) are common in real datasets. Always **detect** first, then decide: drop or impute.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'age': [25, np.nan, 35, 28],
    'salary': [50000, 60000, np.nan, 48000]
})
print(f"With missing values:\n{df}\n")

# Detect missing values
print(f"NaN counts:\n{df.isnull().sum()}\n")

# Option 1: Drop rows with any NaN
print(f"After dropna():\n{df.dropna()}\n")

# Option 2: Fill with column mean (impute)
df_filled = df.copy()
df_filled['age'] = df_filled['age'].fillna(
    df_filled['age'].mean()
)
df_filled['salary'] = df_filled['salary'].fillna(
    df_filled['salary'].median()
)
print(f"After imputation:\n{df_filled}")
# Out:
# With missing values:
#       name   age   salary
# 0    Alice  25.0  50000.0
# 1      Bob   NaN  60000.0
# 2  Charlie  35.0      NaN
# 3    Diana  28.0  48000.0
#
# NaN counts:
# name      0
# age       1
# salary    1
# dtype: int64
#
# After dropna():
#     name   age   salary
# 0  Alice  25.0  50000.0
# 3  Diana  28.0  48000.0
#
# After imputation:
#       name        age   salary
# 0    Alice  25.000000  50000.0
# 1      Bob  29.333333  60000.0
# 2  Charlie  35.000000  50000.0
# 3    Diana  28.000000  48000.0

# %% [markdown]
# ### Sorting & Ranking

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice','Bob','Charlie','Diana','Eve'],
    'age': [25, 30, 35, 28, 42],
    'salary': [70000, 55000, 80000, 48000, 62000]
})

# Sort by salary (descending)
print(f"By salary (desc):")
print(df.sort_values('salary', ascending=False))

# Top 3 earners
print(f"\nTop 3 earners:")
print(df.nlargest(3, 'salary'))

# Sort by multiple columns
print(f"\nBy age then salary:")
print(df.sort_values(['age', 'salary']))
# Out:
# By salary (desc):
#       name  age  salary
# 2  Charlie   35   80000
# 0    Alice   25   70000
# 4      Eve   42   62000
# 1      Bob   30   55000
# 3    Diana   28   48000
#
# Top 3 earners:
#       name  age  salary
# 2  Charlie   35   80000
# 0    Alice   25   70000
# 4      Eve   42   62000
#
# By age then salary:
#       name  age  salary
# 0    Alice   25   70000
# 3    Diana   28   48000
# 1      Bob   30   55000
# 2  Charlie   35   80000
# 4      Eve   42   62000

# %% [markdown]
# ### Part 4 Exercises

# %% [markdown]
# **Exercise 4.1** — Load `data.csv`. Add a computed column `Effort = Pulse * Duration / 60` (effort score). Then add an `Intensity` column using `.apply()` with a lambda:
# - `'Low'` if Calories < 200
# - `'Medium'` if 200 ≤ Calories < 400
# - `'High'` if Calories ≥ 400
#
# Print the first 10 rows showing only `Duration`, `Calories`, `Effort`, `Intensity`.

# %%
# Exercise 4.1

# Load data.csv
data = pd.read_csv('data.csv')
print(data.shape)

# add computed column
data['Effort'] = data['Pulse'] * data['Duration'] / 60
print(data.shape)

# Add intensity column
data['Intensity'] = data['Calories'].apply(
    lambda x: 'Low' if x < 200 else 'Medium' if 200 <= x < 400 else 'High'
)
print(data.shape)

# Print first 10 rows with selected columns
print(f"\n{data[['Duration', 'Calories', 'Effort', 'Intensity']].head(10)}")
# Out:
# (169, 4)
# (169, 5)
# (169, 6)
#
#    Duration  Calories  Effort Intensity
# 0        60     409.1  110.00      High
# 1        60     479.0  117.00      High
# 2        60     340.0  103.00    Medium
# 3        45     282.4   81.75    Medium
# 4        45     406.0   87.75      High
# 5        60     300.0  102.00    Medium
# 6        60     374.0  110.00    Medium
# 7        45     253.3   78.00    Medium
# 8        30     195.1   54.50       Low
# 9        60     269.0   98.00    Medium

# %% [markdown]
# **Exercise 4.2** — Load `data.csv`. Use `rename()` to rename `Duration` → `Duration_min` and `Maxpulse` → `Max_Pulse`. Then drop the `Pulse` column. Print `dtypes` of the resulting DataFrame to confirm the changes.

# %%
# Exercise 4.2
# data.csv
data = pd.read_csv('data.csv')
print(data.shape)

# Rename column names
data = data.rename(columns = {'Duration':'Duration_min', 'Maxpulse':'Max_Pulse'})

# Drop Pulse column
data = data.drop(columns = ['Pulse'])

# Print data types
print(data.dtypes)
# Out:
# (169, 4)
# Duration_min      int64
# Max_Pulse         int64
# Calories        float64
# dtype: object

# %% [markdown]
# **Exercise 4.3** — Load `data.csv`.
# 1. Use `isnull().sum()` to count missing values per column.
# 2. Count rows before and after `dropna()`.
# 3. Use `dropna(subset=['Calories'])` to drop only rows missing Calories. Count rows again.
# 4. Print the row indices that had missing Calories.

# %%
# Exercise 4.3

# load data.csv
data = pd.read_csv('data.csv')
print(data.shape)

def get_count(data):
    return data.isnull().sum()

# data.csv previously loaded
before = get_count(data)
print(f"\nMissing Count:\n{before}")

# Count rows before and after dropna()
dropped = data.dropna(subset=['Calories'])
after = get_count(dropped)
print(f"\nAfter Count:\n{after}")

# Get missing rows
missing = data[data['Calories'].isnull()]
print(missing)
# Out:
# (169, 4)
#
# Missing Count:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64
#
# After Count:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %% [markdown]
# **Exercise 4.4** — Load `data.csv`. Create two filled copies:
# - `df_mean`: fill missing Calories with the **mean**
# - `df_median`: fill missing Calories with the **median**
#
# For each copy, verify no NaN remains in Calories. Print the filled values side-by-side by filtering to rows that originally had missing Calories.

# %%
# Exercise 4.4

# load data.csv
data = pd.read_csv('data.csv')
print(data.shape)

# Create mean copy& fill missing Calories with mean
df_mean = data.copy()
df_mean['Calories'] = df_mean['Calories'].fillna(df_mean['Calories'].mean())
print(f"\nMean:\n{get_count(df_mean)}")

# Create median copy & fill missing Calories with median
df_median = data.copy()
df_median['Calories'] = df_median['Calories'].fillna(df_median['Calories'].median())
print(f"\nMedian:\n{get_count(df_median)}")

# Verify no null values remain
print(f"\nMean copy null values: {df_mean['Calories'].isnull().sum()}")
print(f"Median copy null values: {df_median['Calories'].isnull().sum()}")

# Mask for null rows
mask = data['Calories'].isnull()

# Print filled values side by side
# Create new df on mean/median filled using mask, select Calories column
filled = pd.DataFrame({
    'Mean filled': df_mean.loc[mask, 'Calories'],
    'Median filled': df_median.loc[mask, 'Calories']
})
print(f"\nFilled values:\n{filled}")
# Out:
# (169, 4)
#
# Mean:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
#
# Median:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
#
# Mean copy null values: 0
# Median copy null values: 0
#
# Filled values:
#      Mean filled  Median filled
# 17    375.790244          318.6
# 27    375.790244          318.6
# 91    375.790244          318.6
# 118   375.790244          318.6
# 141   375.790244          318.6

# %% [markdown]
# **Exercise 4.5** — Load `data.csv`.
# 1. Sort by `Calories` descending and print the top 5 rows.
# 2. Use `nlargest(5, 'Calories')` and confirm you get the same result.
# 3. Use `nsmallest(3, 'Duration')` to find the 3 shortest workouts.
# 4. Sort by `Duration` ascending then `Calories` descending (multi-column sort).

# %%
# Exercise 4.5

# load data.csv
data = pd.read_csv('data.csv')
print(data.shape)

# Sort by Cals descending + print top 5 rows
df_cals1 = data.sort_values('Calories', ascending = False)[:5]
print(df_cals1)

# Use nlargest
df_cals2 = data.nlargest(5, 'Calories')
print(f"\n{df_cals2}")

# Use nsmallest
df_dur = data.nsmallest(3, 'Duration')
print(f"\n{df_dur}")

# Sort by duration ascending then cal descending
data_sorted = data.sort_values(['Duration', 'Calories'], ascending = False)
print(f"\n{data_sorted}")
# Out:
# (169, 4)
#      Duration  Pulse  Maxpulse  Calories
# 109       210    137       184    1860.4
# 79        270    100       131    1729.0
# 69        300    108       143    1500.2
# 60        210    108       160    1376.0
# 70        150     97       129    1115.0
#
#      Duration  Pulse  Maxpulse  Calories
# 109       210    137       184    1860.4
# 79        270    100       131    1729.0
# 69        300    108       143    1500.2
# 60        210    108       160    1376.0
# 70        150     97       129    1115.0
#
#      Duration  Pulse  Maxpulse  Calories
# 93         15     80       100      50.5
# 112        15    124       139     124.2
# 58         20    153       172     226.4
#
#      Duration  Pulse  Maxpulse  Calories
# 69        300    108       143    1500.2
# 79        270    100       131    1729.0
# 109       210    137       184    1860.4
# 60        210    108       160    1376.0
# 65        180     90       130     800.4
# ..        ...    ...       ...       ...
# 68         20    106       136     110.4
# 100        20     95       112      77.7
# 89         20     83       107      50.3
# 112        15    124       139     124.2
# 93         15     80       100      50.5
#
# [169 rows x 4 columns]

# %% [markdown]
# ---
# ## Part 5 — GroupBy, Aggregation & Merging
#
# GroupBy implements the **split-apply-combine** pattern: split data into groups, apply an aggregation function, and combine results. Merging joins two DataFrames like SQL JOIN.

# %% [markdown]
# ### GroupBy — Split-Apply-Combine

# %%
import pandas as pd

df = pd.DataFrame({
    'dept': ['Eng','Sales','Eng','HR','Sales','HR'],
    'name': ['Alice','Bob','Charlie','Diana','Eve','Frank'],
    'salary': [70000, 55000, 80000, 48000, 62000, 52000]
})
print(f"Data:\n{df}\n")

# Average salary per department
print(f"Mean salary by dept:")
print(df.groupby('dept')['salary'].mean())

# Multiple aggregations
print(f"\nMultiple stats:")
print(df.groupby('dept')['salary'].agg(
    ['mean', 'min', 'max', 'count']
))

# Group size
print(f"\nEmployees per dept:")
print(df.groupby('dept').size())
# Out:
# Data:
#     dept     name  salary
# 0    Eng    Alice   70000
# 1  Sales      Bob   55000
# 2    Eng  Charlie   80000
# 3     HR    Diana   48000
# 4  Sales      Eve   62000
# 5     HR    Frank   52000
#
# Mean salary by dept:
# dept
# Eng      75000.0
# HR       50000.0
# Sales    58500.0
# Name: salary, dtype: float64
#
# Multiple stats:
#           mean    min    max  count
# dept
# Eng    75000.0  70000  80000      2
# HR     50000.0  48000  52000      2
# Sales  58500.0  55000  62000      2
#
# Employees per dept:
# dept
# Eng      2
# HR       2
# Sales    2
# dtype: int64

# %% [markdown]
# ### Merging & Concatenating
#
# Pandas `merge` is equivalent to SQL JOIN. `concat` stacks DataFrames vertically or horizontally.

# %%
import pandas as pd

# Two related tables
employees = pd.DataFrame({
    'emp_id': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'dept_id': [10, 20, 10, 30]
})

departments = pd.DataFrame({
    'dept_id': [10, 20, 40],
    'dept_name': ['Engineering', 'Sales', 'Marketing']
})

# Inner join (default) — only matching rows
inner = pd.merge(employees, departments, on='dept_id')
print(f"Inner join:\n{inner}\n")

# Left join — keep all employees
left = pd.merge(employees, departments,
                on='dept_id', how='left')
print(f"Left join:\n{left}\n")

# Concat — stack vertically
batch1 = pd.DataFrame({'x': [1,2], 'y': [3,4]})
batch2 = pd.DataFrame({'x': [5,6], 'y': [7,8]})
combined = pd.concat([batch1, batch2], ignore_index=True)
print(f"Concat:\n{combined}")
# Out:
# Inner join:
#    emp_id     name  dept_id    dept_name
# 0       1    Alice       10  Engineering
# 1       2      Bob       20        Sales
# 2       3  Charlie       10  Engineering
#
# Left join:
#    emp_id     name  dept_id    dept_name
# 0       1    Alice       10  Engineering
# 1       2      Bob       20        Sales
# 2       3  Charlie       10  Engineering
# 3       4    Diana       30          NaN
#
# Concat:
#    x  y
# 0  1  3
# 1  2  4
# 2  5  7
# 3  6  8

# %% [markdown]
# ### Apply — Custom Transformations
#
# `apply` lets you run any function over rows or columns. `map` replaces values using a dictionary. These are the tools for custom feature engineering.

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'score': [85, 62, 91],
    'grade_letter': ['A', 'B', 'A']
})
print(f"Original:\n{df}\n")

# Apply lambda to transform a column
df['pass_fail'] = df['score'].apply(
    lambda x: 'Pass' if x >= 70 else 'Fail'
)

# Map categorical values to numbers
df['grade_num'] = df['grade_letter'].map(
    {'A': 4, 'B': 3, 'C': 2}
)

# Apply to entire row (axis=1)
df['summary'] = df.apply(
    lambda row: f"{row['name']}: {row['score']}",
    axis=1
)

print(f"Transformed:\n{df}")
# Out:
# Original:
#       name  score grade_letter
# 0    Alice     85            A
# 1      Bob     62            B
# 2  Charlie     91            A
#
# Transformed:
#       name  score grade_letter pass_fail  grade_num      summary
# 0    Alice     85            A      Pass          4    Alice: 85
# 1      Bob     62            B      Fail          3      Bob: 62
# 2  Charlie     91            A      Pass          4  Charlie: 91

# %% [markdown]
# ### Part 5 Exercises

# %% [markdown]
# **Exercise 5.1** — Load `data.csv`. Group by `Duration` and compute the **mean** `Calories` per group. Print all groups sorted by mean Calories descending. Which `Duration` value has the highest average calorie burn?

# %%
# Exercise 5.1

# %% [markdown]
# **Exercise 5.2** — Load `data.csv`. Group by `Duration` and compute **four statistics** on `Calories` using `.agg(['mean', 'min', 'max', 'count'])`. Print the result. Then find which duration group has the highest `count` (most sessions recorded).

# %%
# Exercise 5.2

# %% [markdown]
# **Exercise 5.3** — Create two DataFrames:
# - `orders`: columns `order_id`, `customer_id`, `amount` (5 rows)
# - `customers`: columns `customer_id`, `name`, `city` (4 rows, with one customer_id not in orders)
#
# Perform an **inner join** and a **left join** on `customer_id`. Print both results and explain the difference in row count.

# %%
# Exercise 5.3

# %% [markdown]
# **Exercise 5.4** — Create two DataFrames `df_jan` and `df_feb` with the same columns (`product`, `sales`). Concatenate them **vertically** with `ignore_index=True`. Add a column `month` to each before concatenating so you can tell which month each row came from. Also create `df_a` and `df_b` with different columns (same index) and concatenate them **horizontally** (`axis=1`).

# %%
# Exercise 5.4

# %% [markdown]
# **Exercise 5.5** — Load `data.csv`.
# 1. Add a `Category` column using `.apply()`:
#    - `'Low'` if Calories < 200, `'Medium'` if 200–400, `'High'` if > 400
# 2. Use `.map()` to create an `Intensity` column from a dictionary mapping Duration values (30, 45, 60) to `'Short'`, `'Moderate'`, `'Long'` (use `.get()` to handle unmapped values as `'Other'`).
# 3. Group by `Category` and count rows per category.

# %%
# Exercise 5.5
